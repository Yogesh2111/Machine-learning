# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('wine_data.csv')

# %%
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      0    14.23        1.71  2.43               15.6        127
# 1      0    13.20        1.78  2.14               11.2        100
# 2      0    13.16        2.36  2.67               18.6        101
# 3      0    14.37        1.95  2.50               16.8        113
# 4      0    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# ...

# %%
df.tail()
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 173      2    13.71        5.65  2.45               20.5         95
# 174      2    13.40        3.91  2.48               23.0        102
# 175      2    13.27        4.28  2.26               20.0        120
# 176      2    13.17        2.59  2.37               20.0        120
# 177      2    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315  Proline
# 173              7.7  0.64         1.74      740
# ...

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     0.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      0.000000   11.030000    0.740000    1.360000          10.600000
# 25%      0.000000   12.362500    1.602500    2.210000          17.200000
# 50%      1.000000   13.050000    1.865000    2.360000          19.500000
# 75%      2.000000   13.677500    3.082500    2.557500          21.500000
# max      2.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# OD280/OD315             0
# Proline                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315', 'Proline'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Class                     3
# Alcohol                 126
# Malic acid              133
# Ash                      79
# Alcalinity of ash        63
# Magnesium                53
# Total phenols            97
# Flavanoids              132
# Nonflavanoid phenols     39
# Proanthocyanins         101
# Color intensity         132
# Hue                      78
# OD280/OD315             122
# Proline                 121
# dtype: int64

# %%
df.corr()
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# OD280/OD315          -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# Length: 178, dtype: bool

# %%
plt.scatter(df['Class'],df['Alcohol'])

# %%
plt.boxplot(df['Alcohol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x252d772d310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x252d772d9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x252d7721f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x252d77390d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x252d7739430>],
#  'means': []}

# %%
plt.boxplot(df['Color intensity'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x252d778c7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x252d778ceb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x252d778c490>],
#  'medians': [<matplotlib.lines.Line2D at 0x252d77995b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x252d7799910>],
#  'means': []}

# %%
plt.boxplot(df['Proline'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x252d76ea310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x252d76b2fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x252d76e1dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x252d76d15b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x252d76d1e20>],
#  'means': []}
